# %%
import pandas as pd

# %%
movies_data=pd.read_csv('tmdb_5000_movies.csv')

# %%
movies_data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
ser=movies_data['runtime']

# %%
ser
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
# 5       139.0
# 6       100.0
# 7       141.0
# 8       153.0
# 9       151.0
# 10      154.0
# 11      106.0
# 12      151.0
# 13      149.0
# 14      143.0
# 15      150.0
# 16      143.0
# 17      136.0
# 18      106.0
# 19      144.0
# 20      136.0
# 21      140.0
# 22      161.0
# 23      113.0
# 24      187.0
# 25      194.0
# 26      147.0
# 27      131.0
# 28      124.0
# 29      143.0
#         ...
# 4773     92.0
# 4774     64.0
# 4775     85.0
# 4776     97.0
# 4777     78.0
# 4778     85.0
# 4779     97.0
# 4780     90.0
# 4781     90.0
# 4782    120.0
# 4783     91.0
# 4784     85.0
# 4785     60.0
# 4786     88.0
# 4787     78.0
# 4788     93.0
# 4789    111.0
# 4790     90.0
# 4791     84.0
# 4792    111.0
# 4793     90.0
# 4794     82.0
# 4795     98.0
# 4796     77.0
# 4797     80.0
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# ...

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
f_name=['Satyam','Aman','Rakesh','Himanshu','Ankit','Pradumn']
l_name=['Seth','Sahu','Kannojiya','Jaswal','Gupta','Dixit']

# %%
# f_name_series=pd.Series(f_name)
f_name_series=pd.Series(f_name,name='names')

# %%
f_name_series
# Out:
# 0      Satyam
# 1        Aman
# 2      Rakesh
# 3    Himanshu
# 4       Ankit
# 5     Pradumn
# Name: names, dtype: object

# %%
names_series=pd.Series(f_name,index=l_name,name='names')

# %%
names_series
# Out:
# Seth           Satyam
# Sahu             Aman
# Kannojiya      Rakesh
# Jaswal       Himanshu
# Gupta           Ankit
# Dixit         Pradumn
# Name: names, dtype: object

# %%
import numpy as np
f_name=np.array(['Satyam','Aman','Rakesh','Himanshu','Ankit','Pradumn'])

# %%
names_series=pd.Series(f_name,index=l_name,name='names')

# %%
names_series
# Out:
# Seth           Satyam
# Sahu             Aman
# Kannojiya      Rakesh
# Jaswal       Himanshu
# Gupta           Ankit
# Dixit         Pradumn
# Name: names, dtype: object

# %%
l_name=('Seth','Sahu','Kannojiya','Jaswal','Gupta','Dixit')

# %%
names_series=pd.Series(f_name,index=l_name,name='names')

# %%
names_series
# Out:
# Seth           Satyam
# Sahu             Aman
# Kannojiya      Rakesh
# Jaswal       Himanshu
# Gupta           Ankit
# Dixit         Pradumn
# Name: names, dtype: object

# %%
dic={
    1:'one',
    2:'two',
    3:'three'
}

# %%
ser2=pd.Series(dic,name='numbers')

# %%
ser2
# Out:
# 1      one
# 2      two
# 3    three
# Name: numbers, dtype: object

# %%
movies_data=pd.read_csv('tmdb_5000_movies.csv',usecols=['runtime'])

# %%
movies_data
# Out:
#       runtime
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
# 5       139.0
# 6       100.0
# 7       141.0
# 8       153.0
# 9       151.0
# 10      154.0
# 11      106.0
# 12      151.0
# 13      149.0
# 14      143.0
# 15      150.0
# 16      143.0
# 17      136.0
# 18      106.0
# 19      144.0
# 20      136.0
# 21      140.0
# 22      161.0
# 23      113.0
# 24      187.0
# 25      194.0
# 26      147.0
# 27      131.0
# 28      124.0
# 29      143.0
# ...       ...
# 4773     92.0
# 4774     64.0
# 4775     85.0
# 4776     97.0
# 4777     78.0
# 4778     85.0
# 4779     97.0
# 4780     90.0
# 4781     90.0
# 4782    120.0
# 4783     91.0
# 4784     85.0
# 4785     60.0
# 4786     88.0
# 4787     78.0
# 4788     93.0
# 4789    111.0
# 4790     90.0
# 4791     84.0
# 4792    111.0
# 4793     90.0
# 4794     82.0
# 4795     98.0
# 4796     77.0
# 4797     80.0
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
#
# ...

# %%
type(movies_data)
# Out:
# pandas.core.frame.DataFrame

# %%
movies_data=pd.read_csv('tmdb_5000_movies.csv',usecol=['runtime'],squeeze=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-61cc2e552269> in <module>()
# ----> 1 movies_data=pd.read_csv('tmdb_5000_movies.csv',usecol=['runtime'],squeeze=True)
#
# TypeError: parser_f() got an unexpected keyword argument 'usecol'
