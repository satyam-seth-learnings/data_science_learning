# %%
import pandas as pd

# %%
df=pd.read_csv('master.csv')

# %%
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# 5         Albania  1987  female    75+ years            1       35600
# 6         Albania  1987  female  35-54 years            6      278800
# 7         Albania  1987  female  25-34 years            4      257200
# 8         Albania  1987    male  55-74 years            1      137500
# 9         Albania  1987  female   5-14 years            0      311000
# 10        Albania  1987  female  55-74 years            0      144600
# 11        Albania  1987    male   5-14 years            0      338200
# ...

# %%
df.country
# Out:
# 0           Albania
# 1           Albania
# 2           Albania
# 3           Albania
# 4           Albania
# 5           Albania
# 6           Albania
# 7           Albania
# 8           Albania
# 9           Albania
# 10          Albania
# 11          Albania
# 12          Albania
# 13          Albania
# 14          Albania
# 15          Albania
# 16          Albania
# 17          Albania
# 18          Albania
# 19          Albania
# 20          Albania
# 21          Albania
# 22          Albania
# 23          Albania
# 24          Albania
# 25          Albania
# 26          Albania
# 27          Albania
# 28          Albania
# 29          Albania
#             ...
# 27790    Uzbekistan
# 27791    Uzbekistan
# 27792    Uzbekistan
# 27793    Uzbekistan
# 27794    Uzbekistan
# 27795    Uzbekistan
# 27796    Uzbekistan
# 27797    Uzbekistan
# 27798    Uzbekistan
# 27799    Uzbekistan
# 27800    Uzbekistan
# 27801    Uzbekistan
# 27802    Uzbekistan
# 27803    Uzbekistan
# ...

# %%
df.country.unique()
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
# ...

# %%
df.country=='Israel'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 27790    False
# 27791    False
# 27792    False
# 27793    False
# 27794    False
# 27795    False
# 27796    False
# 27797    False
# 27798    False
# 27799    False
# 27800    False
# 27801    False
# 27802    False
# 27803    False
# 27804    False
# 27805    False
# 27806    False
# 27807    False
# 27808    False
# 27809    False
# 27810    False
# 27811    False
# 27812    False
# 27813    False
# 27814    False
# 27815    False
# 27816    False
# ...

# %%
df[df.country=='Israel']
# Out:
#       country  year     sex          age  suicides_no  population  \
# 12416  Israel  1985    male    75+ years           24       66600
# 12417  Israel  1985    male  55-74 years           48      249100
# 12418  Israel  1985  female    75+ years           10       75500
# 12419  Israel  1985    male  35-54 years           41      396400
# 12420  Israel  1985  female  55-74 years           28      290900
# 12421  Israel  1985    male  25-34 years           27      324000
# 12422  Israel  1985    male  15-24 years           19      368300
# 12423  Israel  1985  female  35-54 years           19      412800
# 12424  Israel  1985  female  25-34 years           11      324700
# 12425  Israel  1985  female  15-24 years            7      346200
# 12426  Israel  1985  female   5-14 years            0      437800
# 12427  Israel  1985    male   5-14 years            0      461200
# 12428  Israel  1986    male    75+ years           28       70300
# ...

# %%
type(df.country=='Israel')
# Out:
# pandas.core.series.Series

# %%
(df.country=='Israel').dtype
# Out:
# dtype('bool')

# %%
df[(df.country=='Israel') & (df.year==2014)]
# Out:
#       country  year     sex          age  suicides_no  population  \
# 12764  Israel  2014    male    75+ years           32      164959
# 12765  Israel  2014    male  35-54 years          125      925543
# 12766  Israel  2014    male  55-74 years           54      577076
# 12767  Israel  2014    male  25-34 years           41      580208
# 12768  Israel  2014    male  15-24 years           35      633544
# 12769  Israel  2014  female    75+ years           11      236381
# 12770  Israel  2014  female  55-74 years           24      645102
# 12771  Israel  2014  female  35-54 years           29      949566
# 12772  Israel  2014  female  25-34 years           13      576407
# 12773  Israel  2014  female  15-24 years           10      607031
# 12774  Israel  2014    male   5-14 years            7      753317
# 12775  Israel  2014  female   5-14 years            1      717118
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
mask1=df.country=='Israel'
mask2=df.year==2014
df[mask1 & mask2]
# Out:
#       country  year     sex          age  suicides_no  population  \
# 12764  Israel  2014    male    75+ years           32      164959
# 12765  Israel  2014    male  35-54 years          125      925543
# 12766  Israel  2014    male  55-74 years           54      577076
# 12767  Israel  2014    male  25-34 years           41      580208
# 12768  Israel  2014    male  15-24 years           35      633544
# 12769  Israel  2014  female    75+ years           11      236381
# 12770  Israel  2014  female  55-74 years           24      645102
# 12771  Israel  2014  female  35-54 years           29      949566
# 12772  Israel  2014  female  25-34 years           13      576407
# 12773  Israel  2014  female  15-24 years           10      607031
# 12774  Israel  2014    male   5-14 years            7      753317
# 12775  Israel  2014  female   5-14 years            1      717118
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
mask1=df.country=='Israel'
mask2=df.year==2014
mask3=df.year==2015
df[mask1 & (mask2 | mask3)]
# Out:
#       country  year     sex          age  suicides_no  population  \
# 12764  Israel  2014    male    75+ years           32      164959
# 12765  Israel  2014    male  35-54 years          125      925543
# 12766  Israel  2014    male  55-74 years           54      577076
# 12767  Israel  2014    male  25-34 years           41      580208
# 12768  Israel  2014    male  15-24 years           35      633544
# 12769  Israel  2014  female    75+ years           11      236381
# 12770  Israel  2014  female  55-74 years           24      645102
# 12771  Israel  2014  female  35-54 years           29      949566
# 12772  Israel  2014  female  25-34 years           13      576407
# 12773  Israel  2014  female  15-24 years           10      607031
# 12774  Israel  2014    male   5-14 years            7      753317
# 12775  Israel  2014  female   5-14 years            1      717118
# 12776  Israel  2015    male    75+ years           30      168826
# ...

# %%
mask1=df.country=='Israel'
mask2=df.year==2014
mask3=df.year==2015
f_df=df.loc[mask1 & (mask2 | mask3), ['country','year','sex','age','suicides_no']]

# %%
f_df
# Out:
#       country  year     sex          age  suicides_no
# 12764  Israel  2014    male    75+ years           32
# 12765  Israel  2014    male  35-54 years          125
# 12766  Israel  2014    male  55-74 years           54
# 12767  Israel  2014    male  25-34 years           41
# 12768  Israel  2014    male  15-24 years           35
# 12769  Israel  2014  female    75+ years           11
# 12770  Israel  2014  female  55-74 years           24
# 12771  Israel  2014  female  35-54 years           29
# 12772  Israel  2014  female  25-34 years           13
# 12773  Israel  2014  female  15-24 years           10
# 12774  Israel  2014    male   5-14 years            7
# 12775  Israel  2014  female   5-14 years            1
# 12776  Israel  2015    male    75+ years           30
# 12777  Israel  2015    male  55-74 years           65
# 12778  Israel  2015    male  35-54 years           92
# 12779  Israel  2015    male  25-34 years           45
# ...

# %%
mask1=df.country=='Israel'
mask2=df.year==2014
mask3=df.year==2015
mask4=df.sex=='male'
f_df=df.loc[mask1 & mask4 & (mask2 | mask3), ['country','year','sex','age','suicides_no']]
f_df
# Out:
#       country  year   sex          age  suicides_no
# 12764  Israel  2014  male    75+ years           32
# 12765  Israel  2014  male  35-54 years          125
# 12766  Israel  2014  male  55-74 years           54
# 12767  Israel  2014  male  25-34 years           41
# 12768  Israel  2014  male  15-24 years           35
# 12774  Israel  2014  male   5-14 years            7
# 12776  Israel  2015  male    75+ years           30
# 12777  Israel  2015  male  55-74 years           65
# 12778  Israel  2015  male  35-54 years           92
# 12779  Israel  2015  male  25-34 years           45
# 12781  Israel  2015  male  15-24 years           35
# 12786  Israel  2015  male   5-14 years            2

# %%
f_df.sum().suicides_no
# Out:
# 563

# %%
mask1=df.country=='Israel'
mask2=df.year==2014
mask3=df.year==2015
mask4=df.sex=='female'
f_df=df.loc[mask1 & mask4 & (mask2 | mask3), ['country','year','sex','age','suicides_no']]
f_df
# Out:
#       country  year     sex          age  suicides_no
# 12769  Israel  2014  female    75+ years           11
# 12770  Israel  2014  female  55-74 years           24
# 12771  Israel  2014  female  35-54 years           29
# 12772  Israel  2014  female  25-34 years           13
# 12773  Israel  2014  female  15-24 years           10
# 12775  Israel  2014  female   5-14 years            1
# 12780  Israel  2015  female    75+ years           14
# 12782  Israel  2015  female  55-74 years           17
# 12783  Israel  2015  female  25-34 years           13
# 12784  Israel  2015  female  35-54 years           20
# 12785  Israel  2015  female  15-24 years            8
# 12787  Israel  2015  female   5-14 years            1

# %%
f_df.sum().suicides_no
# Out:
# 161

# %%
mask1=df.country=='Ukraine'
mask2=df.year==2014
mask3=df.year==2015
mask4=df.sex=='female'
f_df=df.loc[mask1 & mask4 & (mask2 | mask3), ['country','year','sex','age','suicides_no']]
f_df.sum().suicides_no
# Out:
# 2982

# %%
mask1=df.country=='Ukraine'
mask2=df.year==2014
mask3=df.year==2015
mask4=df.sex=='male'
f_df=df.loc[mask1 & mask4 & (mask2 | mask3), ['country','year','sex','age','suicides_no']]
f_df.sum().suicides_no
# Out:
# 12560
