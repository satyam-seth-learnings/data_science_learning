# %%
import pandas as pd

# %%
movies_data=pd.read_csv("tmdb_5000_movies.csv")

# %%
movies_data.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
movies_data.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
# Selecting Single Column
movies_data['original_title'] # Pandas Series
# Out:
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# 4                                       John Carter
# 5                                      Spider-Man 3
# 6                                           Tangled
# 7                           Avengers: Age of Ultron
# 8            Harry Potter and the Half-Blood Prince
# 9                Batman v Superman: Dawn of Justice
# 10                                 Superman Returns
# 11                                Quantum of Solace
# 12       Pirates of the Caribbean: Dead Man's Chest
# 13                                  The Lone Ranger
# 14                                     Man of Steel
# 15         The Chronicles of Narnia: Prince Caspian
# 16                                     The Avengers
# 17      Pirates of the Caribbean: On Stranger Tides
# ...

# %%
# Selecting Multiple Columns
movies_data[["original_title","budget"]] # Pandas DataFrame
# Out:
#                                    original_title     budget
# 0                                          Avatar  237000000
# 1        Pirates of the Caribbean: At World's End  300000000
# 2                                         Spectre  245000000
# 3                           The Dark Knight Rises  250000000
# 4                                     John Carter  260000000
# 5                                    Spider-Man 3  258000000
# 6                                         Tangled  260000000
# 7                         Avengers: Age of Ultron  280000000
# 8          Harry Potter and the Half-Blood Prince  250000000
# 9              Batman v Superman: Dawn of Justice  250000000
# 10                               Superman Returns  270000000
# 11                              Quantum of Solace  200000000
# 12     Pirates of the Caribbean: Dead Man's Chest  200000000
# 13                                The Lone Ranger  255000000
# ...

# %%
# Select Row
movies_data[0] # Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-d0c1f24a39be> in <module>()
#       1 # Select Row
# ----> 2 movies_data[0] # Error
#
# ...

# %%
movies_data[0:1]
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
movies_data[5:15]
# Out:
#        budget                                             genres  \
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11  200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13  255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14  225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                              homepage      id  \
# 5     http://www.sonypictures.com/movies/spider-man3/     559
# 6        http://disney.go.com/disneypictures/tangled/   38757
# ...

# %%
movies_data.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# Selecting Row Using iloc
movies_data.iloc[0]
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                        150.438
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# ...

# %%
type(movies_data.iloc[0])
# Out:
# pandas.core.series.Series

# %%
movies_data.iloc[0:5]
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
type(movies_data.iloc[0:5])
# Out:
# pandas.core.frame.DataFrame

# %%
# For Geting Rows By Index Number , We Are Pass List Of Index Numbers
movies_data.iloc[[1,3,6,78]]
# Out:
#        budget                                             genres  \
# 1   300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 3   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 6   260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 78  175000000  [{"id": 10751, "name": "Family"}, {"id": 12, "...
#
#                                          homepage      id  \
# 1    http://disney.go.com/disneypictures/pirates/     285
# 3              http://www.thedarkknightrises.com/   49026
# 6    http://disney.go.com/disneypictures/tangled/   38757
# 78  http://movies.disney.com/the-jungle-book-2016  278927
#
#                                              keywords original_language  \
# 1   [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 3   [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 6   [{"id": 1562, "name": "hostage"}, {"id": 2343,...                en
# ...

# %%
# We Are Also Use The iloc For Geting Rows With Specific Columns Only
movies_data.iloc[[1,3,6,2,78],[2,9,4]]
# Out:
#                                          homepage  \
# 1    http://disney.go.com/disneypictures/pirates/
# 3              http://www.thedarkknightrises.com/
# 6    http://disney.go.com/disneypictures/tangled/
# 2     http://www.sonypictures.com/movies/spectre/
# 78  http://movies.disney.com/the-jungle-book-2016
#
#                                  production_companies  \
# 1   [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 3   [{"name": "Legendary Pictures", "id": 923}, {"...
# 6   [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2   [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 78  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                              keywords
# 1   [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 3   [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 6   [{"id": 1562, "name": "hostage"}, {"id": 2343,...
# 2   [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 78  [{"id": 818, "name": "based on novel"}, {"id":...

# %%
movies_data.iloc[[1,3,6,2,78],0:6]
# Out:
#        budget                                             genres  \
# 1   300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 3   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 6   260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 2   245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 78  175000000  [{"id": 10751, "name": "Family"}, {"id": 12, "...
#
#                                          homepage      id  \
# 1    http://disney.go.com/disneypictures/pirates/     285
# 3              http://www.thedarkknightrises.com/   49026
# 6    http://disney.go.com/disneypictures/tangled/   38757
# 2     http://www.sonypictures.com/movies/spectre/  206647
# 78  http://movies.disney.com/the-jungle-book-2016  278927
#
#                                              keywords original_language
# 1   [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 3   [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# ...

# %%
movies_data.iloc[[1,3,6,2,78],2]
# Out:
# 1      http://disney.go.com/disneypictures/pirates/
# 3                http://www.thedarkknightrises.com/
# 6      http://disney.go.com/disneypictures/tangled/
# 2       http://www.sonypictures.com/movies/spectre/
# 78    http://movies.disney.com/the-jungle-book-2016
# Name: homepage, dtype: object
